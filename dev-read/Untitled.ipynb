# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("exampledata.txt")

# %%
wh = np.where(data[:,1] ==13)[0]

# %%
plt.plot(data[:,2][wh])

# %%
plt.scatter(data[:,2][wh],np.ones(len(data[:,2][wh])))

# %%
plt.hist(data[:,2][wh],bins=40)

plt.show()
